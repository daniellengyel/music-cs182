# %%
import numpy as np
from sklearn.manifold import TSNE
import pickle
# import matplotlib.pyplot as plt
import plotly.plotly as py
import plotly.graph_objs as go
import plotly
plotly.offline.init_notebook_mode(connected=True)
import time
import sqlite3
import pandas as pd
import json
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import sys
msd_subset_path='./data/MSD/MillionSongSubset'
msd_subset_data_path=os.path.join(msd_subset_path,'data')
msd_subset_addf_path=os.path.join(msd_subset_path,'AdditionalFiles')
assert os.path.isdir(msd_subset_path),'wrong path' # sanity check
# path to the Million Song Dataset code
# CHANGE IT TO YOUR LOCAL CONFIGURATION
msd_code_path='./data/MSD/MSongsDB'
assert os.path.isdir(msd_code_path),'wrong path' # sanity check
# we add some paths to python so we can import MSD code
# Ubuntu: you can change the environment variable PYTHONPATH
# in your .bashrc file so you do not have to type these lines
sys.path.append(os.path.join(msd_code_path,'PythonSrc') )
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-2-7579f3e958b7> in <module>
#       3 msd_subset_data_path=os.path.join(msd_subset_path,'data')
#       4 msd_subset_addf_path=os.path.join(msd_subset_path,'AdditionalFiles')
# ----> 5 assert os.path.isdir(msd_subset_path),'wrong path' # sanity check
#       6 # path to the Million Song Dataset code
#       7 # CHANGE IT TO YOUR LOCAL CONFIGURATION
#
# AssertionError: wrong path

# %%
song_id_path = "./data/song_track_artist.pkl"

# %% [markdown]
# # Get embedding latent vectors

# %%
genre_embeddings_path = "./data/latent_embeddings.npy"
track_id_embeddings_path = "./data/track_ids_nn.txt"

# %%
genre_embeddings_np = np.load(genre_embeddings_path)
track_ids = np.loadtxt(track_id_embeddings_path, dtype="str")
genre_embeddings_duplicates = pd.DataFrame(genre_embeddings_np, columns=list(range(genre_embeddings_np.shape[1])))
genre_embeddings_duplicates.index = track_ids

# %%
genre_embeddings = genre_embeddings_duplicates[~genre_embeddings_duplicates.index.duplicated(keep='first')]

# %%
len(set(better_df.index.values))

# %%
len(better_df)

# %% [markdown]
# # get genre

# %%
with open("./data/track-genre-mapping.json", "r") as f:
    track_genre = json.load(f)

# %% [markdown]
# # Set track id filter to filtered_track_ids (used throughout)

# %%
filtered_track_ids = genre_embeddings.index[:3000]

# %% [markdown]
# # Get song_id to song_name mapping

# %% [markdown]
# ### using pkl file

# %%
with open(song_id_path, "rb") as f:
    u = pickle._Unpickler(f)
    u.encoding = 'latin1'
    song_name_artist = u.load()

# %%
# getting everything in the right order
song_name_artist_ordered = song_name_artist.set_index(["track_id"]).loc[filtered_track_ids]
# song_artist_str = song_name_artist_ordered.apply(lambda r: "artist: " + r["artist_id"] + ", song: " + r["song_name"], axis=1)
song_artist_str = song_name_artist_ordered["artist_id"]

# %%
song_name_artist_ordered.shape
# Out:
# (2921, 3)

# %%
artists = song_name_artist_ordered["artist_id"].values

# %% [markdown]
# # Mark artists

# %%
famous = ["Lady GaGa", "Kanye West", "Bob Marley", "Bob Dylan", "Shakira", "Jay-Z", "Bon Jovi", "Michael Jackson", 
         "Mariah Carey", "Justin Timberlake", "Oasis"]

# %%
# colors = [int(a in famous) for a in artists]

# %%
# max_popularity = song_popularity.iloc[0].values[0]
# pre_colors = np.array([x[0]/max_popularity for x in song_popularity.values])

# %%
genres = list(set(track_genre.values()))
genres
# Out:
# ['RnB',
#  'Metal',
#  'Rap',
#  'Pop',
#  'Rock',
#  'Blues',
#  'Latin',
#  'World',
#  'Country',
#  'Jazz',
#  'Vocal',
#  'Electronic',
#  'Pop_Rock',
#  'International',
#  'Reggae',
#  'Folk',
#  'New',
#  'Punk']

# %%
genres.index("Blues")
# Out:
# 5

# %%
def foo(t):
    global genres
    if t in track_genre:
        return genres.index(track_genre[t])
    return -1
colors = song_name_artist_ordered.index.map(foo).values

# %%
colors

# %%
for a in artists:
    if "Kurt" in a:
        print(a)

# %%
colors

# %% [markdown]
# # Create t-SNE

# %%
filtered_track_ids
# Out:
# Index(['TRMMMTK128F424EF7C', 'TRMMMKQ128F92EBCB5', 'TRMMMFG128F425087B',
#        'TRMMMQA128F14A454A', 'TRMMWJS12903CBB7F5', 'TRMMWQU12903CF447F',
#        'TRMMGTX128F92FB4D9', 'TRMMHDI128F42442F4', 'TRMMHKG12903CDB1B5',
#        'TRMMCBU128E0791823',
#        ...
#        'TRGQXUP128F92FFC1D', 'TRGQXDF12903D0FB07', 'TRGQXRC128E0780ED4',
#        'TRGQKVS12903CF5E1C', 'TRGQKTS128F428913E', 'TRGQYEQ12903CDFB2B',
#        'TRGQYAK128F9351C6B', 'TRGQYOV128F92DF473', 'TRGZMFZ128F427F03B',
#        'TRGZWLW128F9309DE8'],
#       dtype='object', length=2921)

# %%
embeddings_pure = genre_embeddings.loc[filtered_track_ids].values

# %%
embeddings_pure.shape
# Out:
# (2921, 50)

# %%
X_embedded = TSNE(n_components=2).fit_transform(embeddings_pure)
X_embedded.shape
# Out:
# (2921, 2)

# %%
by_genre_factors = {i: X_embedded[i == colors[:len(X_embedded)]] for i in range(len(genres))}
by_genre_text = {i: song_artist_str[i == colors] for i in range(len(genres))}

# %%
# create a new plot with a title and axis labels
scale = [[0.0, 'rgb(165,0,38)'], [0.1111111111111111, 'rgb(215,48,39)'], [0.2222222222222222, 'rgb(244,109,67)'],
        [0.3333333333333333, 'rgb(253,174,97)'], [0.4444444444444444, 'rgb(254,224,144)'], [0.5555555555555556, 'rgb(224,243,248)'],
        [0.6666666666666666, 'rgb(171,217,233)'],[0.7777777777777778, 'rgb(116,173,209)'], [0.8888888888888888, 'rgb(69,117,180)'],
        [1.0, 'rgb(49,54,149)']]

data = [go.Scatter(x=by_genre_factors[i][:,0], y=by_genre_factors[i][:,1], mode='text',
    marker=dict(
        size=7,
        color=bupu500[i]
    ), text=np.array(by_genre_text[i]), name=genres[i]) for i in range(len(genres))]

# fig = {
#     'data': [
#         {
#             'x': df[df['year']==year]['gdpPercap'],
#             'y': df[df['year']==year]['lifeExp'],
#             'name': year, 'mode': 'markers',
#         } for year in [1952, 1982, 2007]
#     ],
#     'layout': {
#         'xaxis': {'title': 'GDP per Capita', 'type': 'log'},
#         'yaxis': {'title': "Life Expectancy"}
#     }
# }


plotly.offline.iplot(data, filename="tsne-scatter")
# Out:
# <div>
#
#
#             <div id="efbb3568-7aba-4b47-9c14-7d577ec8c426" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("efbb3568-7aba-4b47-9c14-7d577ec8c426")) {
#                     Plotly.newPlot(
#                         'efbb3568-7aba-4b47-9c14-7d577ec8c426',
#                         [{"marker": {"color": "hsl(346.0, 100.0%, 32.0%)", "size": 7}, "mode": "text", "name": "RnB", "text": ["Ayo", "Shai", "Zapp & Roger", "Stevie Wonder", "Aaron Hall", "Anthony David", "Silk", "Ready For The World", "Aaron Hall", "J. Holiday", "Ashanti", "Kelly Price", "Boyz II Men", "Seu Jorge", "Adina Howard", "Minnie Riperton", "Ginuwine", "Rachelle Ferrell", "J. Holiday", "Floetry", "Lighthouse Family", "The Jimmy Castor Bunch", "Alicia Keys", "Ryan Leslie", "Luther Vandross", "Janet Jackson", "Jill Scott", "Funkadelic", "Janet Jackson", "R. Kelly", "Amy Winehouse", "Floetry", "Keyshia Cole / Too Short", "Brian McKnight", "Rihanna", "The Commitments", "The Emotions", "Charlie Wilson", "Brownstone", "Robin Thicke", "Keyshia Cole", "Jill Scott", "Jennifer Lopez", "Shai", "Rihanna", "Ryan Leslie", "Jan Delay", "Mariah Carey", "Jennifer Lopez", "Sade", "Akon", "Janet Jackson", "Alicia Keys", "Jeremih", "Sharon Jones & The Dap-Kings", "Erykah Badu", "John Legend", "Chrisette Michele", "J. Holiday", "Colby O'Donis", "Stevie Wonder", "Aretha Franklin", "Hot Chip", "Heather Headley", "Rihanna", "Beyonc\u00e9 feat. Jay-Z", "Lucy Pearl", "Alicia Keys", "Commodores", "Dave Hollister", "Sade", "Robin Thicke", "Mariah Carey", "Barry White", "Sam Cooke", "Aretha Franklin", "Robin Thicke", "Chrisette Michele", "Lauryn Hill", "Roger", "Stevie Wonder", "The Manhattans", "Maxwell", "Keyshia Cole", "Kaci Brown", "Jermaine Jackson", "Leela James", "Betty Wright", "KC And The Sunshine Band", "Atlantic Starr", "Lucy Pearl", "Kat DeLuna", "Ledisi", "Sade", "Dave Hollister", "Bettye Swann", "Robin Thicke", "Brandy", "Max Herre", "Keyshia Cole", "Alicia Keys", "Aaron Neville", "Beverley Knight", "Rihanna", "Beyonc\u00e9", "Stevie Wonder", "Fantasia", "Amel Larrieux"], "type": "scatter", "uid": "23750689-027c-4ff8-bb94-357ef21b1a5a", "x": [-48.7660026550293, -47.882080078125, -42.20175552368164, -43.185420989990234, -46.4058837890625, -42.555999755859375, -50.2369270324707, -24.38224983215332, -43.45941162109375, -44.60562515258789, -41.255149841308594, -53.114402770996094, -11.471766471862793, -64.85588073730469, -47.8548698425293, -48.29294967651367, -50.54432678222656, -53.02650451660156, -27.605018615722656, -49.49110412597656, -44.35265350341797, -50.437034606933594, -53.3612174987793, -38.02726364135742, -43.141944885253906, -46.53851318359375, -24.99860191345215, -51.20963668823242, -44.813053131103516, -8.671223640441895, -52.829673767089844, -45.45404052734375, -43.32459259033203, -51.878082275390625, -41.948326110839844, -53.754493713378906, -45.751766204833984, -51.1515998840332, -45.27253341674805, -50.80742645263672, -43.99037170410156, -43.836727142333984, -42.303409576416016, -48.41557312011719, -49.5824089050293, -49.76961898803711, -34.9696159362793, -53.94392013549805, -73.49959564208984, -53.112754821777344, -42.990421295166016, -47.31682205200195, -6.216277599334717, -40.49399185180664, -52.250511169433594, -45.47243881225586, -46.772132873535156, -42.644527435302734, -42.6644287109375, -44.62700271606445, -51.66366958618164, -53.78287124633789, -44.02895736694336, -41.795162200927734, -40.60345458984375, -39.41440963745117, -50.924495697021484, -53.35512161254883, -51.185211181640625, -50.34235382080078, -45.37685012817383, -42.388641357421875, -45.81766891479492, -51.418479919433594, -47.24378204345703, -46.05133819580078, -48.59880065917969, -47.314701080322266, -41.35359191894531, -45.85361099243164, -53.2746696472168, -47.39151382446289, -47.05640411376953, -39.782440185546875, -46.29561996459961, -3.4450457096099854, -51.591033935546875, 7.077345371246338, 22.182764053344727, -49.67567825317383, -50.071964263916016, -50.210289001464844, -51.55201721191406, -53.695159912109375, -40.68160629272461, -16.992443084716797, -49.70584487915039, -49.29410934448242, -34.50661849975586, -41.7996711730957, -51.288265228271484, -53.25516128540039, -49.161705017089844, -49.397037506103516, -7.3753461837768555, -52.1 ...

# %%
bupu = cl.scales['11']['div']['RdYlBu']

bupu500 = cl.interp( bupu, 18 )

# %%
 cl.scales['11']
# Out:
# {'div': {'BrBG': ['rgb(84,48,5)',
#    'rgb(140,81,10)',
#    'rgb(191,129,45)',
#    'rgb(223,194,125)',
#    'rgb(246,232,195)',
#    'rgb(245,245,245)',
#    'rgb(199,234,229)',
#    'rgb(128,205,193)',
#    'rgb(53,151,143)',
#    'rgb(1,102,94)',
#    'rgb(0,60,48)'],
#   'PRGn': ['rgb(64,0,75)',
#    'rgb(118,42,131)',
#    'rgb(153,112,171)',
#    'rgb(194,165,207)',
#    'rgb(231,212,232)',
#    'rgb(247,247,247)',
#    'rgb(217,240,211)',
#    'rgb(166,219,160)',
#    'rgb(90,174,97)',
#    'rgb(27,120,55)',
#    'rgb(0,68,27)'],
#   'PiYG': ['rgb(142,1,82)',
#    'rgb(197,27,125)',
#    'rgb(222,119,174)',
#    'rgb(241,182,218)',
#    'rgb(253,224,239)',
#    'rgb(247,247,247)',
#    'rgb(230,245,208)',
#    'rgb(184,225,134)',
#    'rgb(127,188,65)',
#    'rgb(77,146,33)',
#    'rgb(39,100,25)'],
#   'PuOr': ['rgb(127,59,8)',
#    'rgb(179,88,6)',
#    'rgb(224,130,20)',
#    'rgb(253,184,99)',
#    'rgb(254,224,182)',
#    'rgb(247,247,247)',
#    'rgb(216,218,235)',
#    'rgb(178,171,210)',
#    'rgb(128,115,172)',
#    'rgb(84,39,136)',
#    'rgb(45,0,75)'],
#   'RdBu': ['rgb(103,0,31)',
#    'rgb(178,24,43)',
#    'rgb(214,96,77)',
#    'rgb(244,165,130)',
#    'rgb(253,219,199)',
#    'rgb(247,247,247)',
#    'rgb(209,229,240)',
#    'rgb(146,197,222)',
#    'rgb(67,147,195)',
#    'rgb(33,102,172)',
#    'rgb(5,48,97)'],
#   'RdGy': ['rgb(103,0,31)',
#    'rgb(178,24,43)',
#    'rgb(214,96,77)',
#    'rgb(244,165,130)',
#    'rgb(253,219,199)',
#    'rgb(255,255,255)',
#    'rgb(224,224,224)',
#    'rgb(186,186,186)',
#    'rgb(135,135,135)',
#    'rgb(77,77,77)',
#    'rgb(26,26,26)'],
#   'RdYlBu': ['rgb(165,0,38)',
#    'rgb(215,48,39)',
#    'rgb(244,109,67)',
#    'rgb(253,174,97)',
#    'rgb(254,224,144)',
#    'rgb(255,255,191)',
#    'rgb(224,243,248)',
#    'rgb(171,217,233)',
#    'rgb(116,173,209)',
#    'rgb(69,117,180)',
#    'rgb(49,54,149)'],
#   'RdYlGn': ['rgb(165,0,38)',
#    'rgb(215,48,39)',
#    'rgb(244,109,67)',
#    'rgb(253,174,97)',
#    'rgb(254,224,139)',
#    'rgb(255,255,191)',
#    'rgb(217,239,139)',
#    'rgb(166,217,106)',
#    'rgb(102,189,99)',
#    'rgb(26,152,80)',
#    'rgb(0,104,55)'],
#   'Spectral': ['rgb(158,1,66)',
#    'rgb(213,62,79)',
#    'rgb(244,109,67)',
#    'rgb(253,174,97)',
#    'rgb(254,224,139)',
#    'rgb(255,255,191)',
#    'rgb(230,245,152)',
#    'rgb(171,221,164)',
#    'rgb(102,194,165)',
#    'rgb(50,136,189)',
#    'rgb(94,79,162)']},
#  'qual': {'Paired': ['rgb(166,206,227)',
#    'rgb(31,120,180)',
#    'rgb(178,223,138)',
#    'rgb(51,160,44)',
#    'rgb(251,154,153)',
#    'rgb(227,26,28)',
#    'rgb(253,191,111)',
#    'rgb(255,127,0)',
#    'rgb(202,178,214)',
#    'rgb(106,61,154)',
#    'rgb(255,255,153)'],
#   'Set3': ['rgb(141,211,199)',
#    'rgb(255,255,179)',
#    'rgb(190,186,218)',
#    'rgb(251,128,114)',
#    'rgb(128,177,211)',
#    'rgb(253,180,98)',
#    'rgb(179,222,105)',
#    'rgb(252,205,229)',
#    'rgb(217,217,217)',
#    'rgb(188,128,189)',
#    'rgb(204,235,197)']},
#  'seq': {}}

# %%
import colorlover as cl

# %%
# !pip install --user colorlover
# Out:
# DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7.
# Requirement already satisfied: colorlover in /home/daniellengyel/.local/lib/python2.7/site-packages (0.3.0)
